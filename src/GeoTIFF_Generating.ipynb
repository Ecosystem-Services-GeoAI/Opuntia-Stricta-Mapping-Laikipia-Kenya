# %%
# Sentinel-2 spectral divide 10000
import rasterio

file_list = [
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_01_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_02_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_03_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_04_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_05_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_06_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_07_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_08_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_09_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_10_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_11_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_12_Data.tif",
    
]

for fpath in file_list:
    
    with rasterio.open(fpath, 'r+') as src:
        
        data = src.read()  # shape: (bands, height, width)
        
        
        data = data / 10000.0
        
        data = data.astype('float32') 

        src.write(data)

    print(f"{fpath} 已完成除以 10000 的更新。")

print("全部处理完成。")
# Out:
# /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_01_Data.tif 已完成除以 10000 的更新。
# /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_02_Data.tif 已完成除以 10000 的更新。
# /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_03_Data.tif 已完成除以 10000 的更新。
# /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_04_Data.tif 已完成除以 10000 的更新。
# /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_05_Data.tif 已完成除以 10000 的更新。
# /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_06_Data.tif 已完成除以 10000 的更新。
# /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_07_Data.tif 已完成除以 10000 的更新。
# /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_08_Data.tif 已完成除以 10000 的更新。
# ...

# %%
import os
import numpy as np
import rasterio

file_list = [
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_01_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_02_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_03_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_04_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_05_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_06_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_07_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_08_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_09_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_10_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_11_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_12_Data.tif", 
]

out_dir = r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023"
os.makedirs(out_dir, exist_ok=True)

EPS = 1e-6

for i, tif_path in enumerate(file_list):
   
    month = i + 1  
    
    with rasterio.open(tif_path) as src:
        
        profile = src.profile.copy()
        
        data = src.read()
        
        B3 = data[1]  # Green
        B4 = data[2]  # Red
        B8 = data[6]  # NIR
        
        # NDVI
        ndvi = (B8 - B4) / (B8 + B4 + EPS)
        
        # MSAVI
        # MSAVI = (2*NIR + 1 - sqrt((2*NIR+1)^2 - 8*(NIR - RED))) / 2
        msavi = (2.0 * B8 + 1.0) - np.sqrt((2.0 * B8 + 1.0)**2 - 8.0 * (B8 - B4))
        msavi = msavi / 2.0
        
        # GNDVI
        gndvi = (B8 - B3) / (B8 + B3 + EPS)
        
        # NDWI (Green / NIR 版本)
        ndwi = (B3 - B8) / (B3 + B8 + EPS)

        profile.update(
            count=1,            
            dtype=rasterio.float32
        )
        
        month_str = f"2023_{month:02d}"

        ndvi_out_path = os.path.join(out_dir, f"{month_str}_ndvi.tif")
        with rasterio.open(ndvi_out_path, 'w', **profile) as dst:
            dst.write(ndvi.astype(rasterio.float32), 1)

        msavi_out_path = os.path.join(out_dir, f"{month_str}_msavi.tif")
        with rasterio.open(msavi_out_path, 'w', **profile) as dst:
            dst.write(msavi.astype(rasterio.float32), 1)

        gndvi_out_path = os.path.join(out_dir, f"{month_str}_gndvi.tif")
        with rasterio.open(gndvi_out_path, 'w', **profile) as dst:
            dst.write(gndvi.astype(rasterio.float32), 1)

        ndwi_out_path = os.path.join(out_dir, f"{month_str}_ndwi.tif")
        with rasterio.open(ndwi_out_path, 'w', **profile) as dst:
            dst.write(ndwi.astype(rasterio.float32), 1)

    print(f"{tif_path} -> 完成 {month_str} 的所有指数计算并输出。")

print("全部处理完成。")
# Out:
# /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_01_Data.tif -> 完成 2023_01 的所有指数计算并输出。
# /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_02_Data.tif -> 完成 2023_02 的所有指数计算并输出。
# /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_03_Data.tif -> 完成 2023_03 的所有指数计算并输出。
# /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_04_Data.tif -> 完成 2023_04 的所有指数计算并输出。
# /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_05_Data.tif -> 完成 2023_05 的所有指数计算并输出。
# /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_06_Data.tif -> 完成 2023_06 的所有指数计算并输出。
# /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_07_Data.tif -> 完成 2023_07 的所有指数计算并输出。
# ...

# %%
import os
import numpy as np
import rasterio

file_list = [
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_01_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_02_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_03_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_04_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_05_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_06_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_07_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_08_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_09_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_10_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_11_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_12_Data.tif", 
]

out_dir = r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023"
os.makedirs(out_dir, exist_ok=True)


time_stack = []
for tif_path in file_list:
    with rasterio.open(tif_path) as src:
        data = src.read(out_dtype='float32')  
        time_stack.append(data)

time_stack = np.stack(time_stack, axis=0)

with rasterio.open(file_list[0]) as ref:
    profile_ref = ref.profile.copy()

profile_ref.update(
    count=1, 
    dtype=rasterio.float32
)

num_bands = time_stack.shape[1]  
for band_idx in range(num_bands):

    band_data_12 = time_stack[:, band_idx, :, :]  # shape = (12, h, w)

    band_mean = np.mean(band_data_12, axis=0)
    band_min  = np.min(band_data_12, axis=0)
    band_max  = np.max(band_data_12, axis=0)
    band_std  = np.std(band_data_12, axis=0)
    band_range = band_max - band_min

    b_id = band_idx + 1

    # mean
    out_mean = os.path.join(out_dir, f"band{b_id}_mean.tif")
    with rasterio.open(out_mean, 'w', **profile_ref) as dst:
        dst.write(band_mean.astype(rasterio.float32), 1)

    # min
    out_min = os.path.join(out_dir, f"band{b_id}_min.tif")
    with rasterio.open(out_min, 'w', **profile_ref) as dst:
        dst.write(band_min.astype(rasterio.float32), 1)

    # max
    out_max = os.path.join(out_dir, f"band{b_id}_max.tif")
    with rasterio.open(out_max, 'w', **profile_ref) as dst:
        dst.write(band_max.astype(rasterio.float32), 1)

    # std
    out_std = os.path.join(out_dir, f"band{b_id}_std.tif")
    with rasterio.open(out_std, 'w', **profile_ref) as dst:
        dst.write(band_std.astype(rasterio.float32), 1)

    # range
    out_range = os.path.join(out_dir, f"band{b_id}_range.tif")
    with rasterio.open(out_range, 'w', **profile_ref) as dst:
        dst.write(band_range.astype(rasterio.float32), 1)

    print(f"Band {b_id} 统计值输出完成 (mean/min/max/std/range).")

print("所有波段的统计值计算与输出完成。")
# Out:
# Band 1 统计值输出完成 (mean/min/max/std/range).
# Band 2 统计值输出完成 (mean/min/max/std/range).
# Band 3 统计值输出完成 (mean/min/max/std/range).
# Band 4 统计值输出完成 (mean/min/max/std/range).
# Band 5 统计值输出完成 (mean/min/max/std/range).
# Band 6 统计值输出完成 (mean/min/max/std/range).
# Band 7 统计值输出完成 (mean/min/max/std/range).
# Band 8 统计值输出完成 (mean/min/max/std/range).
# Band 9 统计值输出完成 (mean/min/max/std/range).
# Band 10 统计值输出完成 (mean/min/max/std/range).
# 所有波段的统计值计算与输出完成。

# %%
import os
import numpy as np
import rasterio

file_list = [
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_01_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_02_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_03_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_04_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_05_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_06_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_07_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_08_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_09_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_10_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_11_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_12_msavi.tif", 
]

out_dir = r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023"
os.makedirs(out_dir, exist_ok=True)

time_stack = []
for tif_path in file_list:
    with rasterio.open(tif_path) as src:
        
        data = src.read(1).astype(np.float32)
        time_stack.append(data)

time_stack = np.stack(time_stack, axis=0)

with rasterio.open(file_list[0]) as ref:
    profile_ref = ref.profile.copy()

profile_ref.update(
    count=1,
    dtype=rasterio.float32
)

data_mean = np.mean(time_stack, axis=0)  # shape=(height, width)
data_min  = np.min(time_stack, axis=0)
data_max  = np.max(time_stack, axis=0)
data_std  = np.std(time_stack, axis=0)
data_range = data_max - data_min

# mean
out_mean = os.path.join(out_dir, "msavi_mean.tif")
with rasterio.open(out_mean, 'w', **profile_ref) as dst:
    dst.write(data_mean.astype(rasterio.float32), 1)

# min
out_min = os.path.join(out_dir, "msavi_min.tif")
with rasterio.open(out_min, 'w', **profile_ref) as dst:
    dst.write(data_min.astype(rasterio.float32), 1)

# max
out_max = os.path.join(out_dir, "msavi_max.tif")
with rasterio.open(out_max, 'w', **profile_ref) as dst:
    dst.write(data_max.astype(rasterio.float32), 1)

# std
out_std = os.path.join(out_dir, "msavi_std.tif")
with rasterio.open(out_std, 'w', **profile_ref) as dst:
    dst.write(data_std.astype(rasterio.float32), 1)

# range
out_range = os.path.join(out_dir, "msavi_range.tif")
with rasterio.open(out_range, 'w', **profile_ref) as dst:
    dst.write(data_range.astype(rasterio.float32), 1)

print("已完成 12 个月单波段特征的 mean/min/max/std/range 统计并输出。")
# Out:
# 已完成 12 个月单波段特征的 mean/min/max/std/range 统计并输出。

# %%
import pandas as pd
import numpy as np

import math

from sklearn.model_selection import train_test_split

import os
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import GridSearchCV

from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

import geopandas as gpd
from shapely.geometry import box
from shapely.geometry import Point
from sklearn.metrics import accuracy_score, confusion_matrix

import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFECV
from sklearn.model_selection import StratifiedKFold
import numpy as np

# %%
file_path = '/home/ji.song/blue/InvasiveSpecies_Kenya_Annotation/annotation_features_training_compostite_2023_Features_Divide10000.csv'
df = pd.read_csv(file_path)

# %%
all_features_columns = [
    "2023_01_Data_band_1","2023_01_Data_band_2","2023_01_Data_band_3","2023_01_Data_band_4","2023_01_Data_band_5","2023_01_Data_band_6","2023_01_Data_band_7","2023_01_Data_band_8","2023_01_Data_band_9","2023_01_Data_band_10",
    "2023_02_Data_band_1","2023_02_Data_band_2","2023_02_Data_band_3","2023_02_Data_band_4","2023_02_Data_band_5","2023_02_Data_band_6","2023_02_Data_band_7","2023_02_Data_band_8","2023_02_Data_band_9","2023_02_Data_band_10",
    "2023_03_Data_band_1","2023_03_Data_band_2","2023_03_Data_band_3","2023_03_Data_band_4","2023_03_Data_band_5","2023_03_Data_band_6","2023_03_Data_band_7","2023_03_Data_band_8","2023_03_Data_band_9","2023_03_Data_band_10",
    "2023_04_Data_band_1","2023_04_Data_band_2","2023_04_Data_band_3","2023_04_Data_band_4","2023_04_Data_band_5","2023_04_Data_band_6","2023_04_Data_band_7","2023_04_Data_band_8","2023_04_Data_band_9","2023_04_Data_band_10",
    "2023_05_Data_band_1","2023_05_Data_band_2","2023_05_Data_band_3","2023_05_Data_band_4","2023_05_Data_band_5","2023_05_Data_band_6","2023_05_Data_band_7","2023_05_Data_band_8","2023_05_Data_band_9","2023_05_Data_band_10",
    "2023_06_Data_band_1","2023_06_Data_band_2","2023_06_Data_band_3","2023_06_Data_band_4","2023_06_Data_band_5","2023_06_Data_band_6","2023_06_Data_band_7","2023_06_Data_band_8","2023_06_Data_band_9","2023_06_Data_band_10",
    "2023_07_Data_band_1","2023_07_Data_band_2","2023_07_Data_band_3","2023_07_Data_band_4","2023_07_Data_band_5","2023_07_Data_band_6","2023_07_Data_band_7","2023_07_Data_band_8","2023_07_Data_band_9","2023_07_Data_band_10",
    "2023_08_Data_band_1","2023_08_Data_band_2","2023_08_Data_band_3","2023_08_Data_band_4","2023_08_Data_band_5","2023_08_Data_band_6","2023_08_Data_band_7","2023_08_Data_band_8","2023_08_Data_band_9","2023_08_Data_band_10",
    "2023_09_Data_band_1","2023_09_Data_band_2","2023_09_Data_band_3","2023_09_Data_band_4","2023_09_Data_band_5","2023_09_Data_band_6","2023_09_Data_band_7","2023_09_Data_band_8","2023_09_Data_band_9","2023_09_Data_band_10",
    "2023_10_Data_band_1","2023_10_Data_band_2","2023_10_Data_band_3","2023_10_Data_band_4","2023_10_Data_band_5","2023_10_Data_band_6","2023_10_Data_band_7","2023_10_Data_band_8","2023_10_Data_band_9","2023_10_Data_band_10",
    "2023_11_Data_band_1","2023_11_Data_band_2","2023_11_Data_band_3","2023_11_Data_band_4","2023_11_Data_band_5","2023_11_Data_band_6","2023_11_Data_band_7","2023_11_Data_band_8","2023_11_Data_band_9","2023_11_Data_band_10",
    "2023_12_Data_band_1","2023_12_Data_band_2","2023_12_Data_band_3","2023_12_Data_band_4","2023_12_Data_band_5","2023_12_Data_band_6","2023_12_Data_band_7","2023_12_Data_band_8","2023_12_Data_band_9","2023_12_Data_band_10",
    "2023_01_ndvi_band_1","2023_02_ndvi_band_1","2023_03_ndvi_band_1","2023_04_ndvi_band_1","2023_05_ndvi_band_1","2023_06_ndvi_band_1","2023_07_ndvi_band_1","2023_08_ndvi_band_1","2023_09_ndvi_band_1","2023_10_ndvi_band_1","2023_11_ndvi_band_1","2023_12_ndvi_band_1",
    "2023_01_ndwi_band_1","2023_02_ndwi_band_1","2023_03_ndwi_band_1","2023_04_ndwi_band_1","2023_05_ndwi_band_1","2023_06_ndwi_band_1","2023_07_ndwi_band_1","2023_08_ndwi_band_1","2023_09_ndwi_band_1","2023_10_ndwi_band_1","2023_11_ndwi_band_1","2023_12_ndwi_band_1",
    "2023_01_gndvi_band_1","2023_02_gndvi_band_1","2023_03_gndvi_band_1","2023_04_gndvi_band_1","2023_05_gndvi_band_1","2023_06_gndvi_band_1","2023_07_gndvi_band_1","2023_08_gndvi_band_1","2023_09_gndvi_band_1","2023_10_gndvi_band_1","2023_11_gndvi_band_1","2023_12_gndvi_band_1",
    "2023_01_msavi_band_1","2023_02_msavi_band_1","2023_03_msavi_band_1","2023_04_msavi_band_1","2023_05_msavi_band_1","2023_06_msavi_band_1","2023_07_msavi_band_1","2023_08_msavi_band_1","2023_09_msavi_band_1","2023_10_msavi_band_1","2023_11_msavi_band_1","2023_12_msavi_band_1",
    "2023_01_precipitation_band_1","2023_02_precipitation_band_1","2023_03_precipitation_band_1","2023_04_precipitation_band_1","2023_05_precipitation_band_1","2023_06_precipitation_band_1","2023_07_precipitation_band_1","2023_08_precipitation_band_1","2023_09_precipitation_band_1","2023_10_precipitation_band_1","2023_11_precipitation_band_1","2023_12_precipitation_band_1",
    "2023_01_LST_Night_band_1","2023_02_LST_Night_band_1","2023_03_LST_Night_band_1","2023_04_LST_Night_band_1","2023_05_LST_Night_band_1","2023_06_LST_Night_band_1","2023_07_LST_Night_band_1","2023_08_LST_Night_band_1","2023_09_LST_Night_band_1","2023_10_LST_Night_band_1","2023_11_LST_Night_band_1","2023_12_LST_Night_band_1",
    "2023_01_LST_Day_band_1","2023_02_LST_Day_band_1","2023_03_LST_Day_band_1","2023_04_LST_Day_band_1","2023_05_LST_Day_band_1","2023_06_LST_Day_band_1","2023_07_LST_Day_band_1","2023_08_LST_Day_band_1","2023_09_LST_Day_band_1","2023_10_LST_Day_band_1","2023_11_LST_Day_band_1","2023_12_LST_Day_band_1",
    "2023_01_ET_band_1","2023_02_ET_band_1","2023_03_ET_band_1","2023_04_ET_band_1","2023_05_ET_band_1","2023_06_ET_band_1","2023_07_ET_band_1","2023_08_ET_band_1","2023_09_ET_band_1","2023_10_ET_band_1","2023_11_ET_band_1","2023_12_ET_band_1",
    "Slope_band_1_band_1","PublicPolygons_Distance_band_1_band_1","SRTM_ELEV_band_1_band_1","WetLands_Distance_band_1_band_1","WaterBodies_Distance_band_1_band_1","TWI_band_1_band_1",
    "TPI_band_1_band_1","Rivers_Distance_band_1_band_1","Population_KD_band_1_band_1","Livestock_2015_KD_band_1_band_1","Building_KD_band_1_band_1","Aspect_band_1_band_1","CanopyHeight_ROI_band_1"
]

# %%
df = df.dropna(subset=all_features_columns)

# %%
df_GSV = df.loc[df['Class'].isin([1,2,5,7,9])]
df_GSV = df_GSV.loc[df_GSV['Methods'].isin([1,2,3])]
df_GSV = df_GSV.loc[
    (df_GSV['Canopy'] == 1) | (df_GSV['Canopy'].isna())
]

# %%
months = [
    "2023_01", "2023_02", "2023_03", "2023_04", "2023_05", "2023_06", 
    "2023_07", "2023_08", "2023_09", "2023_10", "2023_11", "2023_12"
]

# Calculate statistics for each band across all months
bands = [f"band_{i}" for i in range(1, 11)]

for band in bands:
    band_cols = [f"{month}_Data_{band}" for month in months]
    df_GSV[f"{band}_mean"] = df_GSV[band_cols].mean(axis=1)
    df_GSV[f"{band}_std"] = df_GSV[band_cols].std(axis=1)
    df_GSV[f"{band}_min"] = df_GSV[band_cols].min(axis=1)
    df_GSV[f"{band}_max"] = df_GSV[band_cols].max(axis=1)
    df_GSV[f"{band}_range"] = df_GSV[f"{band}_max"] - df_GSV[f"{band}_min"]

# Calculate annual statistics for additional metrics
metrics = ["ndvi", "ndwi", "gndvi", "msavi", "precipitation", "LST_Night", "LST_Day", "ET"]

for metric in metrics:
    annual_cols = [f"{month}_{metric}_band_1" for month in months]
    df_GSV[f"{metric}_mean"] = df_GSV[annual_cols].mean(axis=1)
    df_GSV[f"{metric}_std"] = df_GSV[annual_cols].std(axis=1)
    df_GSV[f"{metric}_min"] = df_GSV[annual_cols].min(axis=1)
    df_GSV[f"{metric}_max"] = df_GSV[annual_cols].max(axis=1)
    df_GSV[f"{metric}_range"] = df_GSV[f"{metric}_max"] - df_GSV[f"{metric}_min"]

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from dtaidistance import dtw

time_series_groups = {
    "band_1": [f"2023_{str(month).zfill(2)}_Data_band_1" for month in range(1, 13)],
    "band_2": [f"2023_{str(month).zfill(2)}_Data_band_2" for month in range(1, 13)],
    "band_3": [f"2023_{str(month).zfill(2)}_Data_band_3" for month in range(1, 13)],
    "band_4": [f"2023_{str(month).zfill(2)}_Data_band_4" for month in range(1, 13)],
    "band_5": [f"2023_{str(month).zfill(2)}_Data_band_5" for month in range(1, 13)],
    "band_6": [f"2023_{str(month).zfill(2)}_Data_band_6" for month in range(1, 13)],
    "band_7": [f"2023_{str(month).zfill(2)}_Data_band_7" for month in range(1, 13)],
    "band_8": [f"2023_{str(month).zfill(2)}_Data_band_8" for month in range(1, 13)],
    "band_9": [f"2023_{str(month).zfill(2)}_Data_band_9" for month in range(1, 13)],
    "band_10": [f"2023_{str(month).zfill(2)}_Data_band_10" for month in range(1, 13)],

    "ndvi": [f"2023_{str(month).zfill(2)}_ndvi_band_1" for month in range(1, 13)],
    "ndwi": [f"2023_{str(month).zfill(2)}_ndwi_band_1" for month in range(1, 13)],
    "gndvi": [f"2023_{str(month).zfill(2)}_gndvi_band_1" for month in range(1, 13)],
    "msavi": [f"2023_{str(month).zfill(2)}_msavi_band_1" for month in range(1, 13)],
    "precipitation": [f"2023_{str(month).zfill(2)}_precipitation_band_1" for month in range(1, 13)],
    "LST_Night": [f"2023_{str(month).zfill(2)}_LST_Night_band_1" for month in range(1, 13)],
    "LST_Day": [f"2023_{str(month).zfill(2)}_LST_Day_band_1" for month in range(1, 13)],
    "ET": [f"2023_{str(month).zfill(2)}_ET_band_1" for month in range(1, 13)],
    
}


from sklearn.model_selection import GroupShuffleSplit

groups = df_GSV['M100']
labels = df_GSV['Class']

gss = GroupShuffleSplit(test_size=0.2, n_splits=1, random_state=6)

train_idx, test_idx = next(gss.split(df_GSV, labels, groups))

train_df = df_GSV.iloc[train_idx]
test_df = df_GSV.iloc[test_idx]

global_mean_sequences = {}

for key, columns in time_series_groups.items():
    global_mean_sequences[key] = train_df[columns].mean(axis=0).values

def compute_dtw_feature_group(row, group_key, global_mean_sequences):

    row_float = row.values.astype(float)
    global_mean_sequence_float = global_mean_sequences[group_key].astype(float)
    return dtw.distance_fast(row_float, global_mean_sequence_float)


dtw_features = pd.DataFrame(index=train_df.index)
for group_key, columns in time_series_groups.items():

    dtw_features[f"DTW_{group_key}_Distance"] = train_df[columns].apply(
        lambda row: compute_dtw_feature_group(row, group_key, global_mean_sequences), axis=1
    )


for col in dtw_features.columns:
    df_GSV[col] = 0  # 初始化新列
    df_GSV.loc[train_df.index, col] = dtw_features[col]

# %%
global_mean_sequences
# Out:
# {'band_1': array([0.07387101, 0.08602851, 0.08788547, 0.07899952, 0.06590337,
#         0.05771639, 0.07555496, 0.07625916, 0.07977982, 0.08477107,
#         0.06048382, 0.05711997]),
#  'band_2': array([0.11177094, 0.1234082 , 0.1260938 , 0.11433974, 0.10159008,
#         0.09212631, 0.10985172, 0.11538809, 0.11916412, 0.12095255,
#         0.09312837, 0.08837156]),
#  'band_3': array([0.15712948, 0.17444525, 0.17703457, 0.15312906, 0.1272124 ,
#         0.12032417, 0.14938175, 0.162723  , 0.16475854, 0.16649876,
#         0.1025958 , 0.09530923]),
#  'band_4': array([0.19646067, 0.21216054, 0.21638499, 0.19540627, 0.17519621,
#         0.16567769, 0.19265399, 0.20421061, 0.20891804, 0.20760461,
#         0.15344539, 0.14609408]),
#  'band_5': array([0.23431646, 0.2429449 , 0.24593884, 0.24019993, 0.2620438 ,
#         0.23750448, 0.24259642, 0.24442927, 0.25270647, 0.2473803 ,
#         0.26131006, 0.26289242]),
# ...

# %%
sentinel2_multiband_files = [
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_01_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_02_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_03_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_04_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_05_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_06_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_07_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_08_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_09_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_10_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_11_Data.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_12_Data.tif", 
]

# %%
ndvi_files = [
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_01_ndvi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_02_ndvi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_03_ndvi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_04_ndvi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_05_ndvi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_06_ndvi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_07_ndvi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_08_ndvi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_09_ndvi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_10_ndvi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_11_ndvi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_12_ndvi.tif", 
]

# %%
ndwi_files = [
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_01_ndwi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_02_ndwi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_03_ndwi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_04_ndwi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_05_ndwi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_06_ndwi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_07_ndwi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_08_ndwi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_09_ndwi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_10_ndwi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_11_ndwi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_12_ndwi.tif", 
]

# %%
gndvi_files = [
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_01_gndvi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_02_gndvi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_03_gndvi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_04_gndvi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_05_gndvi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_06_gndvi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_07_gndvi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_08_gndvi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_09_gndvi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_10_gndvi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_11_gndvi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_12_gndvi.tif", 
]

# %%
msavi_files = [
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_01_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_02_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_03_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_04_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_05_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_06_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_07_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_08_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_09_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_10_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_11_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_12_msavi.tif", 
]

# %%
msavi_files = [
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_01_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_02_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_03_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_04_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_05_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_06_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_07_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_08_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_09_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_10_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_11_msavi.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_12_msavi.tif", 
]

# %%
# ET
et_files = [
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_01_ET.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_02_ET.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_03_ET.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_04_ET.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_05_ET.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_06_ET.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_07_ET.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_08_ET.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_09_ET.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_10_ET.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_11_ET.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_12_ET.tif",
]

# LST_Day
lst_day_files = [
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_01_LST_Day.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_02_LST_Day.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_03_LST_Day.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_04_LST_Day.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_05_LST_Day.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_06_LST_Day.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_07_LST_Day.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_08_LST_Day.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_09_LST_Day.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_10_LST_Day.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_11_LST_Day.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_12_LST_Day.tif",
]

# LST_Night
lst_night_files = [
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_01_LST_Night.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_02_LST_Night.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_03_LST_Night.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_04_LST_Night.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_05_LST_Night.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_06_LST_Night.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_07_LST_Night.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_08_LST_Night.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_09_LST_Night.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_10_LST_Night.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_11_LST_Night.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_12_LST_Night.tif",
]

# precipitation
precipitation_files = [
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_01_precipitation.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_02_precipitation.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_03_precipitation.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_04_precipitation.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_05_precipitation.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_06_precipitation.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_07_precipitation.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_08_precipitation.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_09_precipitation.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_10_precipitation.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_11_precipitation.tif",
    r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/2023_12_precipitation.tif",
]

# %%
singleband_feature_files = {
    "ndvi": ndvi_files,
    "ndwi": ndwi_files,
    "gndvi": gndvi_files,
    "msavi": msavi_files,
    "precipitation": precipitation_files,
    "LST_Day": lst_day_files,
    "LST_Night": lst_night_files,
    "ET": et_files,

}

# %%
import rasterio
import numpy as np

def read_time_stack_sentinel2(band_index, multiband_files):

    time_stack = []
    ref_profile = None

    for path in multiband_files:
        with rasterio.open(path) as src:
            
            band_data = src.read(band_index)  # shape=(height, width)
            if ref_profile is None:
                ref_profile = src.profile.copy()
            time_stack.append(band_data)

    time_stack = np.stack(time_stack, axis=0)  # shape=(12, h, w)
    return time_stack, ref_profile

# %%
def read_time_stack_singleband(file_list_12):

    time_stack = []
    ref_profile = None

    for path in file_list_12:
        with rasterio.open(path) as src:
            band_data = src.read(1)  # 单波段
            if ref_profile is None:
                ref_profile = src.profile.copy()
            time_stack.append(band_data)

    time_stack = np.stack(time_stack, axis=0)
    return time_stack, ref_profile

# %%
import os
import numpy as np
import rasterio

# %%
out_dir = r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023"
os.makedirs(out_dir, exist_ok=True)

from dtaidistance import dtw

def compute_dtw_distance_series(pixel_series, reference_series):
    p = pixel_series.astype(float)
    r = reference_series.astype(float)
    return dtw.distance_fast(p, r)

for band_id in range(1, 11):
  
    time_stack, ref_profile = read_time_stack_sentinel2(
        band_index=band_id,
        multiband_files=sentinel2_multiband_files
    )
    # time_stack.shape = (12, height, width)
    height, width = time_stack.shape[1], time_stack.shape[2]

    feature_key = f"band_{band_id}"
    ref_series = global_mean_sequences[feature_key]  # shape=(12,)

    dtw_map = np.zeros((height, width), dtype=np.float32)

    for row in range(height):
        for col in range(width):
            pixel_series = time_stack[:, row, col]  # (12,)
            dist_val = compute_dtw_distance_series(pixel_series, ref_series)
            dtw_map[row, col] = dist_val

    ref_profile.update(
        count=1,
        dtype=rasterio.float32
    )
    out_path = os.path.join(out_dir, f"DTW_band_{band_id}.tif")
    with rasterio.open(out_path, 'w', **ref_profile) as dst:
        dst.write(dtw_map, 1)
    
    print(f"[OK] band_{band_id} DTW 计算完成 -> {out_path}")

for feat_name, file_list_12 in singleband_feature_files.items():
   
    time_stack, ref_profile = read_time_stack_singleband(file_list_12)
    height, width = time_stack.shape[1], time_stack.shape[2]

    ref_series = global_mean_sequences[feat_name]

    dtw_map = np.zeros((height, width), dtype=np.float32)

    for row in range(height):
        for col in range(width):
            pixel_series = time_stack[:, row, col]  # (12,)
            dist_val = compute_dtw_distance_series(pixel_series, ref_series)
            dtw_map[row, col] = dist_val

    ref_profile.update(
        count=1,
        dtype=rasterio.float32
    )
    out_path = os.path.join(out_dir, f"DTW_{feat_name}.tif")
    with rasterio.open(out_path, 'w', **ref_profile) as dst:
        dst.write(dtw_map, 1)
    
    print(f"[OK] {feat_name} DTW 计算完成 -> {out_path}")

print("全部 DTW 距离栅格已生成。")
# Out:
# [OK] band_1 DTW 计算完成 -> /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/DTW_band_1.tif
# [OK] band_2 DTW 计算完成 -> /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/DTW_band_2.tif
# [OK] band_3 DTW 计算完成 -> /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/DTW_band_3.tif
# [OK] band_4 DTW 计算完成 -> /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/DTW_band_4.tif
# [OK] band_5 DTW 计算完成 -> /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/DTW_band_5.tif
# [OK] band_6 DTW 计算完成 -> /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/DTW_band_6.tif
# [OK] band_7 DTW 计算完成 -> /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/DTW_band_7.tif
# ...

# %%
out_dir = r"/home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023"
os.makedirs(out_dir, exist_ok=True)

from dtaidistance import dtw

def compute_dtw_distance_series(pixel_series, reference_series):
    p = pixel_series.astype(float)
    r = reference_series.astype(float)
    return dtw.distance_fast(p, r)

# 5) 再处理其他单波段特征
for feat_name, file_list_12 in singleband_feature_files.items():
    # 5.1 读取12个月单波段栅格
    time_stack, ref_profile = read_time_stack_singleband(file_list_12)
    height, width = time_stack.shape[1], time_stack.shape[2]

    # 5.2 取出参考序列
    ref_series = global_mean_sequences[feat_name]

    # 5.3 逐像元计算 DTW
    dtw_map = np.zeros((height, width), dtype=np.float32)

    for row in range(height):
        for col in range(width):
            pixel_series = time_stack[:, row, col]  # (12,)
            dist_val = compute_dtw_distance_series(pixel_series, ref_series)
            dtw_map[row, col] = dist_val

    # 5.4 写出
    ref_profile.update(
        count=1,
        dtype=rasterio.float32
    )
    out_path = os.path.join(out_dir, f"DTW_{feat_name}.tif")
    with rasterio.open(out_path, 'w', **ref_profile) as dst:
        dst.write(dtw_map, 1)
    
    print(f"[OK] {feat_name} DTW 计算完成 -> {out_path}")

print("全部 DTW 距离栅格已生成。")
# Out:
# [OK] ndvi DTW 计算完成 -> /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/DTW_ndvi.tif
# [OK] ndwi DTW 计算完成 -> /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/DTW_ndwi.tif
# [OK] gndvi DTW 计算完成 -> /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/DTW_gndvi.tif
# [OK] msavi DTW 计算完成 -> /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/DTW_msavi.tif
# [OK] precipitation DTW 计算完成 -> /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/DTW_precipitation.tif
# [OK] LST_Day DTW 计算完成 -> /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/DTW_LST_Day.tif
# [OK] LST_Night DTW 计算完成 -> /home/ji.song/blue/InavsiveSpecies_Kenya_FeaturesTIF/2023_Sentinel-2_divide_newVI/2023/DTW_LST_Night.tif
# ...
